# %% [markdown]
# # P4__●ch02_上傳作業3__Lab#2-3Add__ChromeDevTools的第一個小程式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 英文版畫面
# ![image.png](attachment:image.png)

# %% [markdown]
# #
#     ## javascript的程式碼，可直接用複製，但是要注意，第一次貼上，要先設定可「需許貼上」！
#     console.log(new Date().toLocaleString());
#
#     console.log('hi')
#     var t=0;
#     for (var i =0;i<=10;i++){
#         t+=i;
#     }
#     console.log('總和=' + t )

# %%
# 額外要求：要求:其中的10 改為自己的學號末四碼。

## P4__●ch02_上傳作業3__Lab#2-3Add__ChromeDevTools的第一個小程式  ------ end --------- 實驗者：江俊廷99號
