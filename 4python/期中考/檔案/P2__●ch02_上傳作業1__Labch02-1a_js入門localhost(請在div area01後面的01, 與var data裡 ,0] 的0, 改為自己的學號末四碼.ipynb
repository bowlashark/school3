# %% [markdown]
# # ●上傳作業1： Lab#ch02-1a_js入門localhost(請在div area01後面的01, 與var data裡 ,0] 的0, 改為自己的學號末四碼

# %% [markdown]
# # jpg_Lab#ch02-1a_js入門localhost
# ![image.png](attachment:image.png)

# %% [markdown]
# #
#     ~~~~ 本題的補充教學說明：
#     (1)畫面左上方，可看到，是執行python -m http.server 800
#     (2)這個資料夾裡面有兩個檔案。分別是*.html, 與*.js
#     (3)兩個檔案，各有一個要更改的地方：div area01後面的01, 與var data裡 ,0] 的0, 改為自己的學號末四碼。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #
#     可直接複製使用的程式碼。*.html 與　＊.js
#     =============================
#     <!-- index.html -->
#     <!doctype html>
#     <html>
#       <head>
#         <meta charset="utf-8">
#           <title>First JavaScript</title>
#           <script type="text/javascript" src="script.js" async></script>
#         </head>
#       <body>
#          div area01:
#             <div id='viz'></div>
#       </body>
#     </html>
#     =============================
#     // script.js
#     var data = [3, 7, 2, 9, 1, 11, 0];
#     var tot = 0;
#     data.forEach(function(d){
#         tot += d;
#     });
#     console.log('Sum = ' + tot);
#     // outputs 'Sum = 33'
#     document.getElementById('viz').innerHTML = 'Sum = ' + tot;
#     =============================

# %%
# python -m http.server 8000
# 兩個檔案，各有一個要更改的地方：div area01後面的01, 與var data裡 ,0] 的0, 改為自己的學號末四碼。

# %%
# ●上傳作業1： Lab#ch02-1a_js入門localhost   ------ end --------- 實驗者：江俊廷99號
